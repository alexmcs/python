# %%
# https://www.analyticsvidhya.com/blog/2016/02/time-series-forecasting-codes-python/

# %%
import sys
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from scipy.optimize import minimize

import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Pennasol_Trad.csv', sep = ';', header=0, index_col='time')

# %%
X = np.arange(0.0, len(Y), 1)
Y = np.array(dataset['pennasol'].values,dtype=np.float)
fig = plt.figure(figsize=(15,5))
plt.title('Pennasol in traditional retail 2017')
plt.ylabel('liters')
plt.xlabel('2017')
plt.plot(X, Y)
plt.show()

# %%
Y_rolling_mean = dataset['pennasol'].rolling(window=21).mean()
fig = plt.figure(figsize=(15,5))
plt.title('Pennasol in traditional retail 2017')
plt.ylabel('liters')
plt.xlabel('2017')
plt.plot(X, Y)
plt.plot(Y_rolling_mean, "g", label="Rolling mean trend")

plt.show()
